# %%
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
from VGG_hc import VGG19
import time
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0,1'
# %matplotlib inline

# %% [markdown]
# ## Processing

# %%
# 利用torchvision对图像数据预处理
train_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.RandomResizedCrop(224),
    transforms.RandomAffine(degrees=15,scale=(0.8,1.5)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

val_transform = transforms.Compose([
    transforms.Resize(256),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

trainset = torchvision.datasets.ImageFolder(root='train/', transform=train_transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=20, shuffle=True, num_workers=4)

valset = torchvision.datasets.ImageFolder(root='valid/', transform=val_transform)
valloader = torch.utils.data.DataLoader(valset, batch_size=20, shuffle=False, num_workers=4)

# %%
# 展示训练样本和测试样本数
print(len(trainloader))
print(len(valloader))
# CPU 或者 GPU
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
# 初始化网络,加载预训练模型
model = VGG19(num_classes=40, init_weights=False)
model_dict = model.state_dict()
state_dict = torch.load('vgg19-dcbb9e9d.pth')
new_state_dict = {k: v for k, v in state_dict.items() if k in model_dict}
model_dict.update(new_state_dict)
model.load_state_dict(model_dict)
# Out:
# 859
# 119
# <All keys matched successfully>

# %% [markdown]
# ## Training

# %%
# 查看GPU可用情况
if torch.cuda.device_count()>1:
    print('We are using',torch.cuda.device_count(),'GPUs!')
    model = nn.DataParallel(model)
model.to(device)

# 定义loss function和优化器
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=0.0001, momentum=0.9)

# 保存每个epoch后的Accuracy Loss Val_Accuracy
Accuracy = []
Loss = []
Val_Accuracy = []
BEST_VAL_ACC = 0.
# 训练
since = time.time()
for epoch in range(15):
    train_loss = 0.
    train_accuracy = 0.
    run_accuracy = 0.
    run_loss =0.
    total = 0.
    model.train()
    for i,data in enumerate(trainloader,0):
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)  
        # 经典四步
        optimizer.zero_grad()
        outs = model(images)
        loss = criterion(outs, labels)
        loss.backward()
        optimizer.step()
        # 输出状态
        total += labels.size(0)
        run_loss += loss.item()
        _,prediction = torch.max(outs,1)
        run_accuracy += (prediction == labels).sum().item()
        if i % 20 == 19:
            print('epoch {},iter {},train accuracy: {:.4f}%   loss:  {:.4f}'.format(epoch, i+1, 100*run_accuracy/(labels.size(0)*20), run_loss/20))
            train_accuracy += run_accuracy
            train_loss += run_loss
            run_accuracy, run_loss = 0., 0.
    Loss.append(train_loss/total)
    Accuracy.append(100*train_accuracy/total)
    # 可视化训练过程
    fig1, ax1 = plt.subplots(figsize=(11, 8))
    ax1.plot(range(0, epoch+1, 1), Accuracy)
    ax1.set_title("Average trainset accuracy vs epochs")
    ax1.set_xlabel("Epoch")
    ax1.set_ylabel("Avg. train. accuracy")
    plt.savefig('Train_accuracy_vs_epochs.png')
    plt.clf()
    plt.close()
    
    fig2, ax2 = plt.subplots(figsize=(11, 8))
    ax2.plot(range(epoch+1), Loss)
    ax2.set_title("Average trainset loss vs epochs")
    ax2.set_xlabel("Epoch")
    ax2.set_ylabel("Current loss")
    plt.savefig('loss_vs_epochs.png')

    plt.clf()
    plt.close()
    # 验证
    acc = 0.
    model.eval()
    print('waitting for Val...')
    with torch.no_grad():
        accuracy = 0.
        total =0
        for data in valloader:
            images, labels = data
            images = images.to(device)
            labels = labels.to(device)
            out = model(images)
            _, prediction = torch.max(out, 1)
            total += labels.size(0)
            accuracy += (prediction == labels).sum().item()
            acc = 100.*accuracy/total
    print('epoch {}  The ValSet accuracy is {:.4f}% \n'.format(epoch, acc))
    Val_Accuracy.append(acc)
    if acc > BEST_VAL_ACC:
        print('Find Better Model and Saving it...')
        if not os.path.isdir('checkpoint'):
            os.mkdir('checkpoint')
        torch.save(model.state_dict(), './checkpoint/VGG19_Cats_Dogs_hc.pth')
        BEST_VAL_ACC = acc
        print('Saved!')
    
    fig3, ax3 = plt.subplots(figsize=(11, 8))

    ax3.plot(range(epoch+1),Val_Accuracy )
    ax3.set_title("Average Val accuracy vs epochs")
    ax3.set_xlabel("Epoch")
    ax3.set_ylabel("Current Val accuracy")

    plt.savefig('val_accuracy_vs_epoch.png')
    plt.close()
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(time_elapsed // 60, time_elapsed%60))
    print('Now the best val Acc is {:.4f}%'.format(BEST_VAL_ACC))
# Out:
# We are using 2 GPUs!
# epoch 0,iter 20,train accuracy: 3.0000%   loss:  3.7907
# epoch 0,iter 40,train accuracy: 3.2500%   loss:  3.7315
# epoch 0,iter 60,train accuracy: 6.0000%   loss:  3.6596
# epoch 0,iter 80,train accuracy: 5.2500%   loss:  3.6144
# epoch 0,iter 100,train accuracy: 7.2500%   loss:  3.5496
# epoch 0,iter 120,train accuracy: 10.0000%   loss:  3.5219
# epoch 0,iter 140,train accuracy: 8.7500%   loss:  3.4580
# epoch 0,iter 160,train accuracy: 16.2500%   loss:  3.3732
# epoch 0,iter 180,train accuracy: 18.2500%   loss:  3.3297
# epoch 0,iter 200,train accuracy: 18.0000%   loss:  3.2580
# epoch 0,iter 220,train accuracy: 21.0000%   loss:  3.1486
# epoch 0,iter 240,train accuracy: 22.0000%   loss:  3.0233
# epoch 0,iter 260,train accuracy: 22.0000%   loss:  2.9848
# epoch 0,iter 280,train accuracy: 25.5000%   loss:  2.8335
# epoch 0,iter 300,train accuracy: 30.7500%   loss:  2.6605
# epoch 0,iter 320,train accuracy: 30.7500%   loss:  2.5748
# epoch 0,iter 340,train accuracy: 31.0000%   loss:  2.5478
# epoch 0,iter 360,train accuracy: 40.2500%   loss:  2.2594
# epoch 0,iter 380,train accuracy: 37.7500%   loss:  2.2648
# epoch 0,iter 400,train accuracy: 39.7500%   loss:  2.2141
# epoch 0,iter 420,train accuracy: 39.7500%   loss:  2.1721
# epoch 0,iter 440,train accuracy: 37.7500%   loss:  2.1463
# epoch 0,iter 460,train accuracy: 47.0000%   loss:  1.9503
# epoch 0,iter 480,train accuracy: 46.7500%   loss:  1.9625
# epoch 0,iter 500,train accuracy: 43.5000%   loss:  2.0842
# epoch 0,iter 520,train accuracy: 49.7500%   loss:  1.7779
# epoch 0,iter 540,train accuracy: 42.0000%   loss:  1.9302
# epoch 0,iter 560,train accuracy: 45.2500%   loss:  1.9208
# epoch 0,iter 580,train accuracy: 45.7500%   loss:  1.9129
# epoch 0,iter 600,train accuracy: 47.2500%   loss:  1.8967
# epoch 0,iter 620,train accuracy: 54.2500%   loss:  1.7217
# epoch 0,iter 640,train accuracy: 48.5000%   loss:  1.8586
# epoch 0,iter 660,train accuracy: 50.7500%   loss:  1.7966
# epoch 0,iter 680,train accuracy: 53.7500%   loss:  1.7523
# epoch 0,iter 700,train accuracy: 51.2500%   loss:  1.7160
# epoch 0,iter 720,train accuracy: 51.5000%   loss:  1.7658
# epoch 0,iter 740,train accuracy: 49.2500%   loss:  1.8310
# epoch 0,iter 760,train accuracy: 53.2500%   loss:  1.6863
# epoch 0,iter 780,train accuracy: 54.5000%   loss:  1.5289
# epoch 0,iter 800,train accuracy: 51.7500%   loss:  1.7460
# epoch 0,iter 820,train accuracy: 54.2500%   loss:  1.6033
# epoch 0,iter 840,train accuracy: 52.2500%   loss:  1.6260
# waitting for Val...
# epoch 0  The ValSet accuracy is 73.6000%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 8m 9s
# Now the best val Acc is 73.6000%
# epoch 1,iter 20,train accuracy: 58.7500%   loss:  1.3736
# epoch 1,iter 40,train accuracy: 55.0000%   loss:  1.5996
# epoch 1,iter 60,train accuracy: 56.5000%   loss:  1.5553
# epoch 1,iter 80,train accuracy: 54.2500%   loss:  1.6068
# epoch 1,iter 100,train accuracy: 58.0000%   loss:  1.4801
# epoch 1,iter 120,train accuracy: 55.7500%   loss:  1.5765
# epoch 1,iter 140,train accuracy: 53.7500%   loss:  1.6687
# epoch 1,iter 160,train accuracy: 51.7500%   loss:  1.6332
# epoch 1,iter 180,train accuracy: 55.7500%   loss:  1.5330
# epoch 1,iter 200,train accuracy: 55.7500%   loss:  1.5737
# epoch 1,iter 220,train accuracy: 53.0000%   loss:  1.5826
# epoch 1,iter 240,train accuracy: 57.7500%   loss:  1.5404
# epoch 1,iter 260,train accuracy: 61.2500%   loss:  1.3080
# epoch 1,iter 280,train accuracy: 62.7500%   loss:  1.3478
# epoch 1,iter 300,train accuracy: 59.2500%   loss:  1.3434
# epoch 1,iter 320,train accuracy: 55.0000%   loss:  1.5830
# epoch 1,iter 340,train accuracy: 55.5000%   loss:  1.4376
# epoch 1,iter 360,train accuracy: 56.7500%   loss:  1.5348
# epoch 1,iter 380,train accuracy: 60.5000%   loss:  1.4373
# epoch 1,iter 400,train accuracy: 52.2500%   loss:  1.5328
# epoch 1,iter 420,train accuracy: 58.5000%   loss:  1.4141
# epoch 1,iter 440,train accuracy: 59.7500%   loss:  1.3617
# epoch 1,iter 460,train accuracy: 59.0000%   loss:  1.3496
# epoch 1,iter 480,train accuracy: 58.0000%   loss:  1.4076
# epoch 1,iter 500,train accuracy: 58.5000%   loss:  1.5071
# epoch 1,iter 520,train accuracy: 60.0000%   loss:  1.3654
# epoch 1,iter 540,train accuracy: 59.7500%   loss:  1.4586
# epoch 1,iter 560,train accuracy: 57.5000%   loss:  1.4649
# epoch 1,iter 580,train accuracy: 58.5000%   loss:  1.3796
# epoch 1,iter 600,train accuracy: 55.5000%   loss:  1.4725
# epoch 1,iter 620,train accuracy: 58.2500%   loss:  1.3989
# epoch 1,iter 640,train accuracy: 58.2500%   loss:  1.5357
# epoch 1,iter 660,train accuracy: 58.2500%   loss:  1.4296
# epoch 1,iter 680,train accuracy: 59.2500%   loss:  1.4049
# epoch 1,iter 700,train accuracy: 59.2500%   loss:  1.4118
# epoch 1,iter 720,train accuracy: 57.0000%   loss:  1.4669
# epoch 1,iter 740,train accuracy: 56.2500%   loss:  1.4556
# epoch 1,iter 760,train accuracy: 62.0000%   loss:  1.3190
# epoch 1,iter 780,train accuracy: 65.7500%   loss:  1.1763
# epoch 1,iter 800,train accuracy: 60.5000%   loss:  1.4396
# epoch 1,iter 820,train accuracy: 59.7500%   loss:  1.3835
# epoch 1,iter 840,train accuracy: 60.2500%   loss:  1.4369
# waitting for Val...
# epoch 1  The ValSet accuracy is 78.0632%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 16m 17s
# Now the best val Acc is 78.0632%
# epoch 2,iter 20,train accuracy: 60.0000%   loss:  1.4033
# epoch 2,iter 40,train accuracy: 56.2500%   loss:  1.4095
# epoch 2,iter 60,train accuracy: 59.7500%   loss:  1.3190
# epoch 2,iter 80,train accuracy: 62.0000%   loss:  1.2793
# epoch 2,iter 100,train accuracy: 66.0000%   loss:  1.2189
# epoch 2,iter 120,train accuracy: 67.7500%   loss:  1.1675
# epoch 2,iter 140,train accuracy: 65.2500%   loss:  1.2276
# epoch 2,iter 160,train accuracy: 57.7500%   loss:  1.4275
# epoch 2,iter 180,train accuracy: 61.7500%   loss:  1.3637
# epoch 2,iter 200,train accuracy: 63.2500%   loss:  1.3029
# epoch 2,iter 220,train accuracy: 61.2500%   loss:  1.3083
# epoch 2,iter 240,train accuracy: 61.7500%   loss:  1.3622
# epoch 2,iter 260,train accuracy: 62.0000%   loss:  1.2604
# epoch 2,iter 280,train accuracy: 62.0000%   loss:  1.3081
# epoch 2,iter 300,train accuracy: 61.2500%   loss:  1.3164
# epoch 2,iter 320,train accuracy: 62.2500%   loss:  1.2806
# epoch 2,iter 340,train accuracy: 61.2500%   loss:  1.2785
# epoch 2,iter 360,train accuracy: 62.2500%   loss:  1.2535
# epoch 2,iter 380,train accuracy: 62.5000%   loss:  1.3120
# epoch 2,iter 400,train accuracy: 63.7500%   loss:  1.2846
# epoch 2,iter 420,train accuracy: 61.7500%   loss:  1.4154
# epoch 2,iter 440,train accuracy: 63.0000%   loss:  1.2584
# epoch 2,iter 460,train accuracy: 65.7500%   loss:  1.1947
# epoch 2,iter 480,train accuracy: 59.7500%   loss:  1.3812
# epoch 2,iter 500,train accuracy: 63.7500%   loss:  1.2601
# epoch 2,iter 520,train accuracy: 63.5000%   loss:  1.3049
# epoch 2,iter 540,train accuracy: 61.7500%   loss:  1.3218
# epoch 2,iter 560,train accuracy: 60.5000%   loss:  1.3632
# epoch 2,iter 580,train accuracy: 60.2500%   loss:  1.3046
# epoch 2,iter 600,train accuracy: 57.2500%   loss:  1.4454
# epoch 2,iter 620,train accuracy: 58.5000%   loss:  1.4424
# epoch 2,iter 640,train accuracy: 65.0000%   loss:  1.1556
# epoch 2,iter 660,train accuracy: 67.0000%   loss:  1.1613
# epoch 2,iter 680,train accuracy: 65.7500%   loss:  1.1924
# epoch 2,iter 700,train accuracy: 61.0000%   loss:  1.3485
# epoch 2,iter 720,train accuracy: 64.5000%   loss:  1.1912
# epoch 2,iter 740,train accuracy: 67.0000%   loss:  1.1205
# epoch 2,iter 760,train accuracy: 66.0000%   loss:  1.2011
# epoch 2,iter 780,train accuracy: 61.5000%   loss:  1.2970
# epoch 2,iter 800,train accuracy: 62.2500%   loss:  1.2796
# epoch 2,iter 820,train accuracy: 60.7500%   loss:  1.2819
# epoch 2,iter 840,train accuracy: 66.5000%   loss:  1.1943
# waitting for Val...
# epoch 2  The ValSet accuracy is 81.9368%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 24m 23s
# Now the best val Acc is 81.9368%
# epoch 3,iter 20,train accuracy: 65.7500%   loss:  1.1913
# epoch 3,iter 40,train accuracy: 62.7500%   loss:  1.2492
# epoch 3,iter 60,train accuracy: 66.2500%   loss:  1.1851
# epoch 3,iter 80,train accuracy: 63.0000%   loss:  1.2751
# epoch 3,iter 100,train accuracy: 68.2500%   loss:  1.1389
# epoch 3,iter 120,train accuracy: 67.0000%   loss:  1.1637
# epoch 3,iter 140,train accuracy: 65.0000%   loss:  1.2548
# epoch 3,iter 160,train accuracy: 63.5000%   loss:  1.2581
# epoch 3,iter 180,train accuracy: 65.7500%   loss:  1.1335
# epoch 3,iter 200,train accuracy: 66.7500%   loss:  1.0965
# epoch 3,iter 220,train accuracy: 64.2500%   loss:  1.1960
# epoch 3,iter 240,train accuracy: 63.5000%   loss:  1.2053
# epoch 3,iter 260,train accuracy: 68.0000%   loss:  1.1239
# epoch 3,iter 280,train accuracy: 61.5000%   loss:  1.3479
# epoch 3,iter 300,train accuracy: 64.5000%   loss:  1.2294
# epoch 3,iter 320,train accuracy: 66.2500%   loss:  1.1409
# epoch 3,iter 340,train accuracy: 69.7500%   loss:  0.9713
# epoch 3,iter 360,train accuracy: 68.0000%   loss:  1.1109
# epoch 3,iter 380,train accuracy: 66.7500%   loss:  1.1992
# epoch 3,iter 400,train accuracy: 66.0000%   loss:  1.1366
# epoch 3,iter 420,train accuracy: 65.0000%   loss:  1.2213
# epoch 3,iter 440,train accuracy: 62.7500%   loss:  1.2269
# epoch 3,iter 460,train accuracy: 62.7500%   loss:  1.2248
# epoch 3,iter 480,train accuracy: 64.7500%   loss:  1.1966
# epoch 3,iter 500,train accuracy: 69.0000%   loss:  1.0848
# epoch 3,iter 520,train accuracy: 64.0000%   loss:  1.1792
# epoch 3,iter 540,train accuracy: 64.7500%   loss:  1.2451
# epoch 3,iter 560,train accuracy: 66.7500%   loss:  1.2462
# epoch 3,iter 580,train accuracy: 64.7500%   loss:  1.2022
# epoch 3,iter 600,train accuracy: 64.7500%   loss:  1.1433
# epoch 3,iter 620,train accuracy: 65.2500%   loss:  1.2010
# epoch 3,iter 640,train accuracy: 64.5000%   loss:  1.2188
# epoch 3,iter 660,train accuracy: 64.2500%   loss:  1.2336
# epoch 3,iter 680,train accuracy: 67.2500%   loss:  1.1134
# epoch 3,iter 700,train accuracy: 67.2500%   loss:  1.1294
# epoch 3,iter 720,train accuracy: 62.0000%   loss:  1.2631
# epoch 3,iter 740,train accuracy: 68.5000%   loss:  1.1496
# epoch 3,iter 760,train accuracy: 64.7500%   loss:  1.1675
# epoch 3,iter 780,train accuracy: 63.7500%   loss:  1.2201
# epoch 3,iter 800,train accuracy: 64.7500%   loss:  1.2107
# epoch 3,iter 820,train accuracy: 63.2500%   loss:  1.1911
# epoch 3,iter 840,train accuracy: 69.5000%   loss:  1.0992
# waitting for Val...
# epoch 3  The ValSet accuracy is 80.5474%
#
# Training complete in 32m 30s
# Now the best val Acc is 81.9368%
# epoch 4,iter 20,train accuracy: 64.2500%   loss:  1.2582
# epoch 4,iter 40,train accuracy: 67.2500%   loss:  1.1576
# epoch 4,iter 60,train accuracy: 67.5000%   loss:  1.1285
# epoch 4,iter 80,train accuracy: 69.2500%   loss:  1.0499
# epoch 4,iter 100,train accuracy: 69.2500%   loss:  1.0197
# epoch 4,iter 120,train accuracy: 67.2500%   loss:  1.1607
# epoch 4,iter 140,train accuracy: 69.7500%   loss:  1.0562
# epoch 4,iter 160,train accuracy: 65.5000%   loss:  1.0614
# epoch 4,iter 180,train accuracy: 67.7500%   loss:  1.1607
# epoch 4,iter 200,train accuracy: 64.2500%   loss:  1.1563
# epoch 4,iter 220,train accuracy: 70.0000%   loss:  1.0951
# epoch 4,iter 240,train accuracy: 68.0000%   loss:  1.1361
# epoch 4,iter 260,train accuracy: 70.5000%   loss:  0.9962
# epoch 4,iter 280,train accuracy: 69.7500%   loss:  1.0948
# epoch 4,iter 300,train accuracy: 67.5000%   loss:  1.1067
# epoch 4,iter 320,train accuracy: 67.2500%   loss:  1.0901
# epoch 4,iter 340,train accuracy: 61.0000%   loss:  1.3036
# epoch 4,iter 360,train accuracy: 64.0000%   loss:  1.1462
# epoch 4,iter 380,train accuracy: 71.0000%   loss:  0.9484
# epoch 4,iter 400,train accuracy: 66.0000%   loss:  1.2151
# epoch 4,iter 420,train accuracy: 66.7500%   loss:  1.1018
# epoch 4,iter 440,train accuracy: 65.5000%   loss:  1.1540
# epoch 4,iter 460,train accuracy: 67.2500%   loss:  1.0818
# epoch 4,iter 480,train accuracy: 68.2500%   loss:  1.0629
# epoch 4,iter 500,train accuracy: 69.0000%   loss:  1.0846
# epoch 4,iter 520,train accuracy: 68.7500%   loss:  0.9865
# epoch 4,iter 540,train accuracy: 66.0000%   loss:  1.1793
# epoch 4,iter 560,train accuracy: 64.5000%   loss:  1.2020
# epoch 4,iter 580,train accuracy: 66.0000%   loss:  1.2236
# epoch 4,iter 600,train accuracy: 66.2500%   loss:  1.1604
# epoch 4,iter 620,train accuracy: 68.0000%   loss:  1.0687
# epoch 4,iter 640,train accuracy: 66.2500%   loss:  1.1276
# epoch 4,iter 660,train accuracy: 66.7500%   loss:  1.0989
# epoch 4,iter 680,train accuracy: 69.2500%   loss:  1.1090
# epoch 4,iter 700,train accuracy: 65.2500%   loss:  1.2016
# epoch 4,iter 720,train accuracy: 64.0000%   loss:  1.2570
# epoch 4,iter 740,train accuracy: 67.2500%   loss:  1.1568
# epoch 4,iter 760,train accuracy: 66.2500%   loss:  1.1255
# epoch 4,iter 780,train accuracy: 66.2500%   loss:  1.0661
# epoch 4,iter 800,train accuracy: 65.7500%   loss:  1.1676
# epoch 4,iter 820,train accuracy: 71.2500%   loss:  1.1054
# epoch 4,iter 840,train accuracy: 67.7500%   loss:  1.1640
# waitting for Val...
# epoch 4  The ValSet accuracy is 83.4105%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 40m 37s
# Now the best val Acc is 83.4105%
# epoch 5,iter 20,train accuracy: 69.2500%   loss:  1.0757
# epoch 5,iter 40,train accuracy: 73.0000%   loss:  0.9804
# epoch 5,iter 60,train accuracy: 66.0000%   loss:  1.1702
# epoch 5,iter 80,train accuracy: 67.0000%   loss:  1.1263
# epoch 5,iter 100,train accuracy: 67.5000%   loss:  1.0990
# epoch 5,iter 120,train accuracy: 68.7500%   loss:  1.0646
# epoch 5,iter 140,train accuracy: 64.5000%   loss:  1.1876
# epoch 5,iter 160,train accuracy: 65.0000%   loss:  1.1981
# epoch 5,iter 180,train accuracy: 69.0000%   loss:  1.0290
# epoch 5,iter 200,train accuracy: 71.7500%   loss:  1.0027
# epoch 5,iter 220,train accuracy: 70.7500%   loss:  0.9487
# epoch 5,iter 240,train accuracy: 67.0000%   loss:  1.0346
# epoch 5,iter 260,train accuracy: 67.2500%   loss:  1.0160
# epoch 5,iter 280,train accuracy: 71.5000%   loss:  1.0474
# epoch 5,iter 300,train accuracy: 66.2500%   loss:  1.0889
# epoch 5,iter 320,train accuracy: 68.0000%   loss:  1.1202
# epoch 5,iter 340,train accuracy: 69.2500%   loss:  0.9858
# epoch 5,iter 360,train accuracy: 67.0000%   loss:  1.1028
# epoch 5,iter 380,train accuracy: 66.5000%   loss:  1.1029
# epoch 5,iter 400,train accuracy: 67.0000%   loss:  1.1879
# epoch 5,iter 420,train accuracy: 66.2500%   loss:  1.0645
# epoch 5,iter 440,train accuracy: 68.5000%   loss:  1.1091
# epoch 5,iter 460,train accuracy: 62.7500%   loss:  1.2551
# epoch 5,iter 480,train accuracy: 67.2500%   loss:  1.1334
# epoch 5,iter 500,train accuracy: 67.2500%   loss:  1.1203
# epoch 5,iter 520,train accuracy: 74.5000%   loss:  0.9116
# epoch 5,iter 540,train accuracy: 70.2500%   loss:  0.9719
# epoch 5,iter 560,train accuracy: 67.2500%   loss:  1.1766
# epoch 5,iter 580,train accuracy: 67.5000%   loss:  1.0062
# epoch 5,iter 600,train accuracy: 67.7500%   loss:  1.1160
# epoch 5,iter 620,train accuracy: 67.2500%   loss:  1.1249
# epoch 5,iter 640,train accuracy: 69.7500%   loss:  1.1377
# epoch 5,iter 660,train accuracy: 65.5000%   loss:  1.1375
# epoch 5,iter 680,train accuracy: 71.7500%   loss:  1.0776
# epoch 5,iter 700,train accuracy: 67.2500%   loss:  1.1790
# epoch 5,iter 720,train accuracy: 69.2500%   loss:  1.0581
# epoch 5,iter 740,train accuracy: 69.0000%   loss:  0.9746
# epoch 5,iter 760,train accuracy: 69.2500%   loss:  0.9919
# epoch 5,iter 780,train accuracy: 69.0000%   loss:  1.0401
# epoch 5,iter 800,train accuracy: 68.5000%   loss:  1.1251
# epoch 5,iter 820,train accuracy: 68.5000%   loss:  1.0572
# epoch 5,iter 840,train accuracy: 68.7500%   loss:  1.1222
# waitting for Val...
# epoch 5  The ValSet accuracy is 83.3684%
#
# Training complete in 48m 41s
# Now the best val Acc is 83.4105%
# epoch 6,iter 20,train accuracy: 70.2500%   loss:  1.0099
# epoch 6,iter 40,train accuracy: 70.0000%   loss:  1.0572
# epoch 6,iter 60,train accuracy: 65.5000%   loss:  1.1955
# epoch 6,iter 80,train accuracy: 69.0000%   loss:  1.0657
# epoch 6,iter 100,train accuracy: 71.7500%   loss:  0.9645
# epoch 6,iter 120,train accuracy: 69.7500%   loss:  0.9935
# epoch 6,iter 140,train accuracy: 69.7500%   loss:  1.0480
# epoch 6,iter 160,train accuracy: 69.5000%   loss:  1.0642
# epoch 6,iter 180,train accuracy: 66.2500%   loss:  1.0597
# epoch 6,iter 200,train accuracy: 68.7500%   loss:  1.0745
# epoch 6,iter 220,train accuracy: 70.0000%   loss:  1.0232
# epoch 6,iter 240,train accuracy: 69.5000%   loss:  1.0559
# epoch 6,iter 260,train accuracy: 68.5000%   loss:  1.0205
# epoch 6,iter 280,train accuracy: 68.0000%   loss:  1.0943
# epoch 6,iter 300,train accuracy: 65.7500%   loss:  1.0998
# epoch 6,iter 320,train accuracy: 69.0000%   loss:  1.0078
# epoch 6,iter 340,train accuracy: 73.5000%   loss:  1.0021
# epoch 6,iter 360,train accuracy: 67.7500%   loss:  1.0790
# epoch 6,iter 380,train accuracy: 73.5000%   loss:  0.9280
# epoch 6,iter 400,train accuracy: 66.2500%   loss:  1.0716
# epoch 6,iter 420,train accuracy: 68.0000%   loss:  1.0864
# epoch 6,iter 440,train accuracy: 66.2500%   loss:  1.0716
# epoch 6,iter 460,train accuracy: 67.0000%   loss:  1.1594
# epoch 6,iter 480,train accuracy: 65.7500%   loss:  1.1047
# epoch 6,iter 500,train accuracy: 70.0000%   loss:  1.0838
# epoch 6,iter 520,train accuracy: 69.7500%   loss:  1.0506
# epoch 6,iter 540,train accuracy: 73.0000%   loss:  0.9316
# epoch 6,iter 560,train accuracy: 68.2500%   loss:  1.0423
# epoch 6,iter 580,train accuracy: 68.0000%   loss:  1.0735
# epoch 6,iter 600,train accuracy: 70.2500%   loss:  0.9385
# epoch 6,iter 620,train accuracy: 69.0000%   loss:  1.1381
# epoch 6,iter 640,train accuracy: 72.2500%   loss:  1.0079
# epoch 6,iter 660,train accuracy: 66.7500%   loss:  1.1137
# epoch 6,iter 680,train accuracy: 72.5000%   loss:  0.9356
# epoch 6,iter 700,train accuracy: 63.0000%   loss:  1.2314
# epoch 6,iter 720,train accuracy: 74.5000%   loss:  0.8962
# epoch 6,iter 740,train accuracy: 69.7500%   loss:  1.0616
# epoch 6,iter 760,train accuracy: 67.2500%   loss:  1.0529
# epoch 6,iter 780,train accuracy: 66.0000%   loss:  1.0472
# epoch 6,iter 800,train accuracy: 72.2500%   loss:  0.9335
# epoch 6,iter 820,train accuracy: 68.7500%   loss:  1.0977
# epoch 6,iter 840,train accuracy: 69.5000%   loss:  1.0515
# waitting for Val...
# epoch 6  The ValSet accuracy is 84.3368%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 56m 46s
# Now the best val Acc is 84.3368%
# epoch 7,iter 20,train accuracy: 72.5000%   loss:  0.8600
# epoch 7,iter 40,train accuracy: 77.0000%   loss:  0.9070
# epoch 7,iter 60,train accuracy: 69.7500%   loss:  0.9688
# epoch 7,iter 80,train accuracy: 67.2500%   loss:  1.0845
# epoch 7,iter 100,train accuracy: 67.7500%   loss:  1.0786
# epoch 7,iter 120,train accuracy: 69.7500%   loss:  0.9946
# epoch 7,iter 140,train accuracy: 70.7500%   loss:  1.0865
# epoch 7,iter 160,train accuracy: 70.5000%   loss:  1.0334
# epoch 7,iter 180,train accuracy: 72.7500%   loss:  0.9642
# epoch 7,iter 200,train accuracy: 68.2500%   loss:  1.0693
# epoch 7,iter 220,train accuracy: 69.0000%   loss:  1.0110
# epoch 7,iter 240,train accuracy: 74.5000%   loss:  0.8840
# epoch 7,iter 260,train accuracy: 74.7500%   loss:  0.9029
# epoch 7,iter 280,train accuracy: 70.5000%   loss:  0.9892
# epoch 7,iter 300,train accuracy: 72.5000%   loss:  0.9180
# epoch 7,iter 320,train accuracy: 65.2500%   loss:  1.1363
# epoch 7,iter 340,train accuracy: 70.0000%   loss:  1.1096
# epoch 7,iter 360,train accuracy: 70.2500%   loss:  1.0068
# epoch 7,iter 380,train accuracy: 64.5000%   loss:  1.2010
# epoch 7,iter 400,train accuracy: 69.7500%   loss:  0.9789
# epoch 7,iter 420,train accuracy: 72.2500%   loss:  0.9078
# epoch 7,iter 440,train accuracy: 70.7500%   loss:  1.0158
# epoch 7,iter 460,train accuracy: 69.5000%   loss:  1.0826
# epoch 7,iter 480,train accuracy: 69.7500%   loss:  1.0570
# epoch 7,iter 500,train accuracy: 69.0000%   loss:  1.1078
# epoch 7,iter 520,train accuracy: 70.5000%   loss:  0.9331
# epoch 7,iter 540,train accuracy: 69.2500%   loss:  1.0722
# epoch 7,iter 560,train accuracy: 71.0000%   loss:  0.9245
# epoch 7,iter 580,train accuracy: 70.0000%   loss:  1.0063
# epoch 7,iter 600,train accuracy: 68.2500%   loss:  1.0956
# epoch 7,iter 620,train accuracy: 73.0000%   loss:  0.9599
# epoch 7,iter 640,train accuracy: 70.5000%   loss:  1.0263
# epoch 7,iter 660,train accuracy: 71.5000%   loss:  0.9930
# epoch 7,iter 680,train accuracy: 71.0000%   loss:  1.0333
# epoch 7,iter 700,train accuracy: 70.0000%   loss:  1.1077
# epoch 7,iter 720,train accuracy: 69.2500%   loss:  1.0211
# epoch 7,iter 740,train accuracy: 67.7500%   loss:  1.0368
# epoch 7,iter 760,train accuracy: 71.5000%   loss:  0.9502
# epoch 7,iter 780,train accuracy: 72.2500%   loss:  0.9529
# epoch 7,iter 800,train accuracy: 70.7500%   loss:  0.9833
# epoch 7,iter 820,train accuracy: 68.5000%   loss:  1.0325
# epoch 7,iter 840,train accuracy: 73.0000%   loss:  0.9349
# waitting for Val...
# epoch 7  The ValSet accuracy is 84.6737%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 64m 51s
# Now the best val Acc is 84.6737%
# epoch 8,iter 20,train accuracy: 72.0000%   loss:  0.9120
# epoch 8,iter 40,train accuracy: 69.2500%   loss:  0.9865
# epoch 8,iter 60,train accuracy: 68.7500%   loss:  1.0732
# epoch 8,iter 80,train accuracy: 72.5000%   loss:  0.9523
# epoch 8,iter 100,train accuracy: 70.5000%   loss:  0.9828
# epoch 8,iter 120,train accuracy: 75.2500%   loss:  0.7881
# epoch 8,iter 140,train accuracy: 69.2500%   loss:  0.9008
# epoch 8,iter 160,train accuracy: 71.0000%   loss:  0.9555
# epoch 8,iter 180,train accuracy: 66.0000%   loss:  1.1713
# epoch 8,iter 200,train accuracy: 70.7500%   loss:  0.9331
# epoch 8,iter 220,train accuracy: 71.2500%   loss:  1.0441
# epoch 8,iter 240,train accuracy: 68.7500%   loss:  1.0452
# epoch 8,iter 260,train accuracy: 75.2500%   loss:  0.7899
# epoch 8,iter 280,train accuracy: 70.2500%   loss:  1.0276
# epoch 8,iter 300,train accuracy: 68.0000%   loss:  1.0413
# epoch 8,iter 320,train accuracy: 68.5000%   loss:  1.0674
# epoch 8,iter 340,train accuracy: 70.7500%   loss:  1.0322
# epoch 8,iter 360,train accuracy: 70.7500%   loss:  1.0552
# epoch 8,iter 380,train accuracy: 72.7500%   loss:  0.9616
# epoch 8,iter 400,train accuracy: 68.7500%   loss:  1.0844
# epoch 8,iter 420,train accuracy: 69.7500%   loss:  0.9774
# epoch 8,iter 440,train accuracy: 70.2500%   loss:  0.9422
# epoch 8,iter 460,train accuracy: 73.0000%   loss:  0.9305
# epoch 8,iter 480,train accuracy: 68.5000%   loss:  1.0314
# epoch 8,iter 500,train accuracy: 72.7500%   loss:  0.9693
# epoch 8,iter 520,train accuracy: 69.2500%   loss:  1.0408
# epoch 8,iter 540,train accuracy: 67.0000%   loss:  1.0231
# epoch 8,iter 560,train accuracy: 69.0000%   loss:  0.9695
# epoch 8,iter 580,train accuracy: 72.7500%   loss:  0.8751
# epoch 8,iter 600,train accuracy: 78.2500%   loss:  0.8167
# epoch 8,iter 620,train accuracy: 73.5000%   loss:  0.9661
# epoch 8,iter 640,train accuracy: 69.7500%   loss:  1.0325
# epoch 8,iter 660,train accuracy: 73.0000%   loss:  0.8537
# epoch 8,iter 680,train accuracy: 73.2500%   loss:  1.0066
# epoch 8,iter 700,train accuracy: 73.7500%   loss:  0.9109
# epoch 8,iter 720,train accuracy: 70.0000%   loss:  1.0731
# epoch 8,iter 740,train accuracy: 69.0000%   loss:  0.9980
# epoch 8,iter 760,train accuracy: 71.2500%   loss:  0.9579
# epoch 8,iter 780,train accuracy: 65.5000%   loss:  1.0902
# epoch 8,iter 800,train accuracy: 71.2500%   loss:  0.9762
# epoch 8,iter 820,train accuracy: 69.0000%   loss:  0.9841
# epoch 8,iter 840,train accuracy: 68.7500%   loss:  1.0589
# waitting for Val...
# epoch 8  The ValSet accuracy is 85.2211%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 72m 56s
# Now the best val Acc is 85.2211%
# epoch 9,iter 20,train accuracy: 73.0000%   loss:  0.9226
# epoch 9,iter 40,train accuracy: 74.2500%   loss:  0.8568
# epoch 9,iter 60,train accuracy: 72.0000%   loss:  0.9534
# epoch 9,iter 80,train accuracy: 73.2500%   loss:  0.9143
# epoch 9,iter 100,train accuracy: 70.5000%   loss:  0.9825
# epoch 9,iter 120,train accuracy: 74.0000%   loss:  0.8701
# epoch 9,iter 140,train accuracy: 68.5000%   loss:  1.0174
# epoch 9,iter 160,train accuracy: 72.0000%   loss:  0.9601
# epoch 9,iter 180,train accuracy: 70.5000%   loss:  0.9922
# epoch 9,iter 200,train accuracy: 70.0000%   loss:  1.0306
# epoch 9,iter 220,train accuracy: 71.0000%   loss:  0.9838
# epoch 9,iter 240,train accuracy: 72.2500%   loss:  0.9234
# epoch 9,iter 260,train accuracy: 72.7500%   loss:  0.9310
# epoch 9,iter 280,train accuracy: 71.0000%   loss:  0.9667
# epoch 9,iter 300,train accuracy: 73.2500%   loss:  0.9104
# epoch 9,iter 320,train accuracy: 69.5000%   loss:  0.9556
# epoch 9,iter 340,train accuracy: 74.0000%   loss:  0.9142
# epoch 9,iter 360,train accuracy: 73.2500%   loss:  0.9476
# epoch 9,iter 380,train accuracy: 69.5000%   loss:  0.9970
# epoch 9,iter 400,train accuracy: 71.7500%   loss:  0.9772
# epoch 9,iter 420,train accuracy: 75.0000%   loss:  0.9100
# epoch 9,iter 440,train accuracy: 70.2500%   loss:  0.9714
# epoch 9,iter 460,train accuracy: 72.2500%   loss:  0.9534
# epoch 9,iter 480,train accuracy: 72.0000%   loss:  0.9768
# epoch 9,iter 500,train accuracy: 70.7500%   loss:  1.0123
# epoch 9,iter 520,train accuracy: 72.2500%   loss:  0.9796
# epoch 9,iter 540,train accuracy: 73.2500%   loss:  0.9878
# epoch 9,iter 560,train accuracy: 66.0000%   loss:  1.0862
# epoch 9,iter 580,train accuracy: 70.7500%   loss:  0.9633
# epoch 9,iter 600,train accuracy: 71.2500%   loss:  0.9782
# epoch 9,iter 620,train accuracy: 72.7500%   loss:  0.9036
# epoch 9,iter 640,train accuracy: 71.2500%   loss:  0.8959
# epoch 9,iter 660,train accuracy: 70.0000%   loss:  0.9515
# epoch 9,iter 680,train accuracy: 69.7500%   loss:  1.0184
# epoch 9,iter 700,train accuracy: 70.7500%   loss:  1.0734
# epoch 9,iter 720,train accuracy: 75.2500%   loss:  0.8940
# epoch 9,iter 740,train accuracy: 70.2500%   loss:  1.0060
# epoch 9,iter 760,train accuracy: 71.0000%   loss:  0.9287
# epoch 9,iter 780,train accuracy: 71.7500%   loss:  1.0171
# epoch 9,iter 800,train accuracy: 73.2500%   loss:  0.9106
# epoch 9,iter 820,train accuracy: 71.0000%   loss:  0.9247
# epoch 9,iter 840,train accuracy: 71.2500%   loss:  0.9109
# waitting for Val...
# epoch 9  The ValSet accuracy is 85.1368%
#
# Training complete in 81m 0s
# Now the best val Acc is 85.2211%
# epoch 10,iter 20,train accuracy: 72.2500%   loss:  0.8962
# epoch 10,iter 40,train accuracy: 72.0000%   loss:  0.9291
# epoch 10,iter 60,train accuracy: 70.2500%   loss:  1.0464
# epoch 10,iter 80,train accuracy: 75.2500%   loss:  0.7729
# epoch 10,iter 100,train accuracy: 73.2500%   loss:  0.9300
# epoch 10,iter 120,train accuracy: 76.7500%   loss:  0.8432
# epoch 10,iter 140,train accuracy: 70.5000%   loss:  1.0151
# epoch 10,iter 160,train accuracy: 71.5000%   loss:  0.9739
# epoch 10,iter 180,train accuracy: 72.7500%   loss:  0.9557
# epoch 10,iter 200,train accuracy: 68.0000%   loss:  1.0736
# epoch 10,iter 220,train accuracy: 74.5000%   loss:  0.8767
# epoch 10,iter 240,train accuracy: 73.0000%   loss:  0.8606
# epoch 10,iter 260,train accuracy: 76.5000%   loss:  0.8411
# epoch 10,iter 280,train accuracy: 74.7500%   loss:  0.8949
# epoch 10,iter 300,train accuracy: 73.0000%   loss:  0.9189
# epoch 10,iter 320,train accuracy: 67.2500%   loss:  1.0687
# epoch 10,iter 340,train accuracy: 72.2500%   loss:  0.9284
# epoch 10,iter 360,train accuracy: 69.2500%   loss:  0.9919
# epoch 10,iter 380,train accuracy: 75.7500%   loss:  0.8900
# epoch 10,iter 400,train accuracy: 70.5000%   loss:  1.0421
# epoch 10,iter 420,train accuracy: 74.5000%   loss:  0.8835
# epoch 10,iter 440,train accuracy: 69.0000%   loss:  0.9979
# epoch 10,iter 460,train accuracy: 74.5000%   loss:  0.8027
# epoch 10,iter 480,train accuracy: 70.5000%   loss:  1.0317
# epoch 10,iter 500,train accuracy: 76.2500%   loss:  0.8139
# epoch 10,iter 520,train accuracy: 68.5000%   loss:  1.1345
# epoch 10,iter 540,train accuracy: 72.0000%   loss:  1.0245
# epoch 10,iter 560,train accuracy: 75.5000%   loss:  0.8756
# epoch 10,iter 580,train accuracy: 71.2500%   loss:  0.9751
# epoch 10,iter 600,train accuracy: 72.0000%   loss:  0.9196
# epoch 10,iter 620,train accuracy: 74.5000%   loss:  0.8472
# epoch 10,iter 640,train accuracy: 75.5000%   loss:  0.8840
# epoch 10,iter 660,train accuracy: 77.5000%   loss:  0.7269
# epoch 10,iter 680,train accuracy: 68.7500%   loss:  1.0353
# epoch 10,iter 700,train accuracy: 75.2500%   loss:  0.9070
# epoch 10,iter 720,train accuracy: 71.7500%   loss:  0.9891
# epoch 10,iter 740,train accuracy: 70.7500%   loss:  0.9213
# epoch 10,iter 760,train accuracy: 75.2500%   loss:  0.8604
# epoch 10,iter 780,train accuracy: 72.5000%   loss:  0.8824
# epoch 10,iter 800,train accuracy: 72.7500%   loss:  0.9210
# epoch 10,iter 820,train accuracy: 70.5000%   loss:  1.0301
# epoch 10,iter 840,train accuracy: 71.5000%   loss:  0.9544
# waitting for Val...
# epoch 10  The ValSet accuracy is 86.2316%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 89m 5s
# Now the best val Acc is 86.2316%
# epoch 11,iter 20,train accuracy: 69.0000%   loss:  1.0335
# epoch 11,iter 40,train accuracy: 73.0000%   loss:  0.8541
# epoch 11,iter 60,train accuracy: 73.7500%   loss:  0.8616
# epoch 11,iter 80,train accuracy: 71.5000%   loss:  0.9369
# epoch 11,iter 100,train accuracy: 75.2500%   loss:  0.8679
# epoch 11,iter 120,train accuracy: 73.7500%   loss:  0.9186
# epoch 11,iter 140,train accuracy: 69.7500%   loss:  0.9901
# epoch 11,iter 160,train accuracy: 73.5000%   loss:  0.9093
# epoch 11,iter 180,train accuracy: 74.0000%   loss:  0.8692
# epoch 11,iter 200,train accuracy: 68.7500%   loss:  1.0562
# epoch 11,iter 220,train accuracy: 73.5000%   loss:  0.8786
# epoch 11,iter 240,train accuracy: 74.0000%   loss:  0.8559
# epoch 11,iter 260,train accuracy: 74.5000%   loss:  0.8614
# epoch 11,iter 280,train accuracy: 73.7500%   loss:  0.9902
# epoch 11,iter 300,train accuracy: 73.2500%   loss:  0.8409
# epoch 11,iter 320,train accuracy: 74.2500%   loss:  0.8692
# epoch 11,iter 340,train accuracy: 72.2500%   loss:  0.9068
# epoch 11,iter 360,train accuracy: 74.0000%   loss:  0.8946
# epoch 11,iter 380,train accuracy: 74.5000%   loss:  0.8474
# epoch 11,iter 400,train accuracy: 76.7500%   loss:  0.8356
# epoch 11,iter 420,train accuracy: 72.2500%   loss:  0.9133
# epoch 11,iter 440,train accuracy: 73.2500%   loss:  0.9374
# epoch 11,iter 460,train accuracy: 72.5000%   loss:  0.9535
# epoch 11,iter 480,train accuracy: 70.7500%   loss:  1.0101
# epoch 11,iter 500,train accuracy: 74.2500%   loss:  0.9119
# epoch 11,iter 520,train accuracy: 72.2500%   loss:  0.9358
# epoch 11,iter 540,train accuracy: 74.0000%   loss:  0.8989
# epoch 11,iter 560,train accuracy: 71.7500%   loss:  0.9371
# epoch 11,iter 580,train accuracy: 70.2500%   loss:  0.9039
# epoch 11,iter 600,train accuracy: 76.2500%   loss:  0.8512
# epoch 11,iter 620,train accuracy: 73.0000%   loss:  0.9167
# epoch 11,iter 640,train accuracy: 71.7500%   loss:  0.9721
# epoch 11,iter 660,train accuracy: 71.7500%   loss:  0.9440
# epoch 11,iter 680,train accuracy: 71.7500%   loss:  0.8315
# epoch 11,iter 700,train accuracy: 72.2500%   loss:  1.0003
# epoch 11,iter 720,train accuracy: 72.7500%   loss:  0.9013
# epoch 11,iter 740,train accuracy: 72.2500%   loss:  1.0063
# epoch 11,iter 760,train accuracy: 74.0000%   loss:  0.9167
# epoch 11,iter 780,train accuracy: 73.5000%   loss:  0.9010
# epoch 11,iter 800,train accuracy: 74.2500%   loss:  0.8033
# epoch 11,iter 820,train accuracy: 70.2500%   loss:  0.9892
# epoch 11,iter 840,train accuracy: 71.0000%   loss:  0.9472
# waitting for Val...
# epoch 11  The ValSet accuracy is 85.4316%
#
# Training complete in 97m 9s
# Now the best val Acc is 86.2316%
# epoch 12,iter 20,train accuracy: 73.0000%   loss:  0.8170
# epoch 12,iter 40,train accuracy: 72.5000%   loss:  0.8865
# epoch 12,iter 60,train accuracy: 79.2500%   loss:  0.7702
# epoch 12,iter 80,train accuracy: 71.2500%   loss:  0.9134
# epoch 12,iter 100,train accuracy: 72.2500%   loss:  0.8721
# epoch 12,iter 120,train accuracy: 71.2500%   loss:  0.9737
# epoch 12,iter 140,train accuracy: 73.2500%   loss:  0.8185
# epoch 12,iter 160,train accuracy: 76.0000%   loss:  0.8427
# epoch 12,iter 180,train accuracy: 72.5000%   loss:  0.9207
# epoch 12,iter 200,train accuracy: 76.5000%   loss:  0.8496
# epoch 12,iter 220,train accuracy: 70.0000%   loss:  0.9741
# epoch 12,iter 240,train accuracy: 79.7500%   loss:  0.6688
# epoch 12,iter 260,train accuracy: 74.7500%   loss:  0.9110
# epoch 12,iter 280,train accuracy: 78.0000%   loss:  0.8037
# epoch 12,iter 300,train accuracy: 71.5000%   loss:  0.9112
# epoch 12,iter 320,train accuracy: 75.5000%   loss:  0.8655
# epoch 12,iter 340,train accuracy: 70.7500%   loss:  1.0000
# epoch 12,iter 360,train accuracy: 71.0000%   loss:  0.9323
# epoch 12,iter 380,train accuracy: 74.5000%   loss:  0.8328
# epoch 12,iter 400,train accuracy: 69.7500%   loss:  0.9413
# epoch 12,iter 420,train accuracy: 74.2500%   loss:  0.8724
# epoch 12,iter 440,train accuracy: 72.5000%   loss:  0.9257
# epoch 12,iter 460,train accuracy: 73.7500%   loss:  0.8465
# epoch 12,iter 480,train accuracy: 72.7500%   loss:  0.9637
# epoch 12,iter 500,train accuracy: 75.5000%   loss:  0.8227
# epoch 12,iter 520,train accuracy: 71.7500%   loss:  0.8915
# epoch 12,iter 540,train accuracy: 73.7500%   loss:  0.8726
# epoch 12,iter 560,train accuracy: 72.7500%   loss:  0.9073
# epoch 12,iter 580,train accuracy: 74.5000%   loss:  0.8235
# epoch 12,iter 600,train accuracy: 76.2500%   loss:  0.8397
# epoch 12,iter 620,train accuracy: 73.7500%   loss:  0.9231
# epoch 12,iter 640,train accuracy: 73.5000%   loss:  0.9335
# epoch 12,iter 660,train accuracy: 72.5000%   loss:  0.9258
# epoch 12,iter 680,train accuracy: 70.2500%   loss:  0.9783
# epoch 12,iter 700,train accuracy: 72.5000%   loss:  0.9746
# epoch 12,iter 720,train accuracy: 72.7500%   loss:  0.9214
# epoch 12,iter 740,train accuracy: 73.0000%   loss:  0.9050
# epoch 12,iter 760,train accuracy: 73.2500%   loss:  0.9416
# epoch 12,iter 780,train accuracy: 77.5000%   loss:  0.8291
# epoch 12,iter 800,train accuracy: 75.5000%   loss:  0.8622
# epoch 12,iter 820,train accuracy: 73.2500%   loss:  0.9702
# epoch 12,iter 840,train accuracy: 75.5000%   loss:  0.8372
# waitting for Val...
# epoch 12  The ValSet accuracy is 86.5263%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 105m 15s
# Now the best val Acc is 86.5263%
# epoch 13,iter 20,train accuracy: 72.2500%   loss:  0.8896
# epoch 13,iter 40,train accuracy: 72.2500%   loss:  0.8678
# epoch 13,iter 60,train accuracy: 74.5000%   loss:  0.7904
# epoch 13,iter 80,train accuracy: 75.2500%   loss:  0.8399
# epoch 13,iter 100,train accuracy: 75.7500%   loss:  0.7855
# epoch 13,iter 120,train accuracy: 73.5000%   loss:  0.9325
# epoch 13,iter 140,train accuracy: 74.0000%   loss:  0.8658
# epoch 13,iter 160,train accuracy: 76.2500%   loss:  0.7720
# epoch 13,iter 180,train accuracy: 70.7500%   loss:  0.8493
# epoch 13,iter 200,train accuracy: 73.0000%   loss:  0.9183
# epoch 13,iter 220,train accuracy: 75.5000%   loss:  0.8152
# epoch 13,iter 240,train accuracy: 75.5000%   loss:  0.8190
# epoch 13,iter 260,train accuracy: 73.7500%   loss:  0.8380
# epoch 13,iter 280,train accuracy: 72.5000%   loss:  0.9345
# epoch 13,iter 300,train accuracy: 75.7500%   loss:  0.7991
# epoch 13,iter 320,train accuracy: 72.5000%   loss:  0.9316
# epoch 13,iter 340,train accuracy: 76.2500%   loss:  0.7812
# epoch 13,iter 360,train accuracy: 75.0000%   loss:  0.8570
# epoch 13,iter 380,train accuracy: 72.7500%   loss:  0.9320
# epoch 13,iter 400,train accuracy: 73.7500%   loss:  0.9462
# epoch 13,iter 420,train accuracy: 73.7500%   loss:  0.9062
# epoch 13,iter 440,train accuracy: 74.7500%   loss:  0.8655
# epoch 13,iter 460,train accuracy: 73.0000%   loss:  0.8980
# epoch 13,iter 480,train accuracy: 70.7500%   loss:  1.0120
# epoch 13,iter 500,train accuracy: 74.0000%   loss:  0.8815
# epoch 13,iter 520,train accuracy: 72.2500%   loss:  0.8735
# epoch 13,iter 540,train accuracy: 73.0000%   loss:  0.9699
# epoch 13,iter 560,train accuracy: 75.2500%   loss:  0.8230
# epoch 13,iter 580,train accuracy: 71.0000%   loss:  0.9703
# epoch 13,iter 600,train accuracy: 76.5000%   loss:  0.7999
# epoch 13,iter 620,train accuracy: 73.0000%   loss:  0.8553
# epoch 13,iter 640,train accuracy: 78.5000%   loss:  0.7180
# epoch 13,iter 660,train accuracy: 69.2500%   loss:  0.9199
# epoch 13,iter 680,train accuracy: 77.2500%   loss:  0.7578
# epoch 13,iter 700,train accuracy: 75.0000%   loss:  0.8240
# epoch 13,iter 720,train accuracy: 77.2500%   loss:  0.8271
# epoch 13,iter 740,train accuracy: 71.5000%   loss:  0.9421
# epoch 13,iter 760,train accuracy: 76.0000%   loss:  0.7529
# epoch 13,iter 780,train accuracy: 75.5000%   loss:  0.9023
# epoch 13,iter 800,train accuracy: 75.0000%   loss:  0.8024
# epoch 13,iter 820,train accuracy: 73.2500%   loss:  0.9187
# epoch 13,iter 840,train accuracy: 76.0000%   loss:  0.8475
# waitting for Val...
# epoch 13  The ValSet accuracy is 87.2842%
#
# Find Better Model and Saving it...
# Saved!
# Training complete in 113m 24s
# Now the best val Acc is 87.2842%
# epoch 14,iter 20,train accuracy: 74.5000%   loss:  0.8382
# epoch 14,iter 40,train accuracy: 73.0000%   loss:  0.8599
# epoch 14,iter 60,train accuracy: 78.5000%   loss:  0.7236
# epoch 14,iter 80,train accuracy: 78.2500%   loss:  0.7894
# epoch 14,iter 100,train accuracy: 75.0000%   loss:  0.8132
# epoch 14,iter 120,train accuracy: 76.2500%   loss:  0.7937
# epoch 14,iter 140,train accuracy: 71.2500%   loss:  0.9492
# epoch 14,iter 160,train accuracy: 76.0000%   loss:  0.8449
# epoch 14,iter 180,train accuracy: 77.2500%   loss:  0.7676
# epoch 14,iter 200,train accuracy: 74.0000%   loss:  0.9363
# epoch 14,iter 220,train accuracy: 73.5000%   loss:  0.9135
# epoch 14,iter 240,train accuracy: 76.7500%   loss:  0.8562
# epoch 14,iter 260,train accuracy: 72.5000%   loss:  0.8938
# epoch 14,iter 280,train accuracy: 74.0000%   loss:  0.8535
# epoch 14,iter 300,train accuracy: 73.2500%   loss:  0.9290
# epoch 14,iter 320,train accuracy: 76.2500%   loss:  0.8109
# epoch 14,iter 340,train accuracy: 72.5000%   loss:  0.9240
# epoch 14,iter 360,train accuracy: 78.5000%   loss:  0.7554
# epoch 14,iter 380,train accuracy: 74.2500%   loss:  0.8815
# epoch 14,iter 400,train accuracy: 69.7500%   loss:  0.9823
# epoch 14,iter 420,train accuracy: 73.7500%   loss:  0.8782
# epoch 14,iter 440,train accuracy: 78.5000%   loss:  0.8172
# epoch 14,iter 460,train accuracy: 73.0000%   loss:  0.8873
# epoch 14,iter 480,train accuracy: 74.7500%   loss:  0.8444
# epoch 14,iter 500,train accuracy: 74.2500%   loss:  0.8640
# epoch 14,iter 520,train accuracy: 72.0000%   loss:  0.8987
# epoch 14,iter 540,train accuracy: 74.2500%   loss:  0.9226
# epoch 14,iter 560,train accuracy: 75.7500%   loss:  0.8070
# epoch 14,iter 580,train accuracy: 70.5000%   loss:  0.9630
# epoch 14,iter 600,train accuracy: 74.7500%   loss:  0.8206
# epoch 14,iter 620,train accuracy: 74.7500%   loss:  0.7848
# epoch 14,iter 640,train accuracy: 77.5000%   loss:  0.7784
# epoch 14,iter 660,train accuracy: 80.0000%   loss:  0.7414
# epoch 14,iter 680,train accuracy: 76.7500%   loss:  0.7594
# epoch 14,iter 700,train accuracy: 74.5000%   loss:  0.7804
# epoch 14,iter 720,train accuracy: 73.0000%   loss:  0.8530
# epoch 14,iter 740,train accuracy: 75.0000%   loss:  0.8265
# epoch 14,iter 760,train accuracy: 74.5000%   loss:  0.8661
# epoch 14,iter 780,train accuracy: 74.2500%   loss:  0.8218
# epoch 14,iter 800,train accuracy: 70.7500%   loss:  0.9396
# epoch 14,iter 820,train accuracy: 73.5000%   loss:  0.8972
# epoch 14,iter 840,train accuracy: 75.0000%   loss:  0.8562
# waitting for Val...
# epoch 14  The ValSet accuracy is 86.4842%
#
# Training complete in 121m 31s
# Now the best val Acc is 87.2842%
